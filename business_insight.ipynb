# %%
import pandas as pd
import plotly.express as px

# 1. โหลดข้อมูล
df = pd.read_csv('cleaned_data.csv')

# ---------------------------------------------------------
# กราฟที่ 1: Donut Chart สัดส่วนช่องทางที่มีอิทธิพล (S_Influence)
# ---------------------------------------------------------
main_cats = ['โซเชียลมีเดีย', 'แพลตฟอร์มวิดีโอ', 'โทรทัศน์', 'สื่อ ณ จุดขาย', 'แอปพลิเคชั่นแชท/ส่งเมสเสจ']
cat_counts = {cat: df['S_Influence'].str.contains(cat).sum() for cat in main_cats}

other_cats = ['เว็บไซต์', 'บิลบอร์ด/ป้ายโฆษณา', 'รถเมล์/รถไฟฟ้า']
other_sum = sum([df['S_Influence'].str.contains(cat).sum() for cat in other_cats])
cat_counts['อื่นๆ'] = other_sum

df_pie = pd.DataFrame(list(cat_counts.items()), columns=['Platform', 'Count'])

fig1 = px.pie(
    df_pie, 
    values='Count', 
    names='Platform', 
    title='1. สัดส่วนช่องทางที่มีอิทธิพลต่อการตัดสินใจซื้อ (S_Influence)', 
    hole=0.4, # เปลี่ยนเป็น Donut Chart เพื่อความทันสมัย
    color_discrete_sequence=prof_colors
)
fig1.update_traces(textinfo='percent+label', textfont_size=12)
fig1.update_layout(
    title_font=dict(size=18, family="Tahoma", color="#333"),
    legend=dict(orientation="h", yanchor="bottom", y=-0.2, xanchor="center", x=0.5),
    margin=dict(t=60, b=60, l=40, r=40),
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig1.show()

# ---------------------------------------------------------
# กราฟที่ 2: Bar Chart แนวนอน เรียงลำดับ (Sorted Bar Chart)
# ---------------------------------------------------------
all_categories = main_cats + other_cats
counts = {cat: df['S_Influence'].str.contains(cat).sum() for cat in all_categories}

df_influence = pd.DataFrame(list(counts.items()), columns=['Platform', 'Count']).sort_values(by='Count', ascending=True)

fig2 = px.bar(
    df_influence, 
    x='Count', 
    y='Platform', 
    title='จำนวนผู้ได้รับอิทธิพลจากโฆษณาจำแนกตามช่องทาง', 
    orientation='h', 
    text_auto=True,
    color='Count',
    color_continuous_scale='Blues' # ใช้โทนสีฟ้าเข้มไล่ระดับ
)
fig2.update_layout(
    title_font=dict(size=18, family="Tahoma", color="#333"),
    xaxis_title="จำนวนผู้ใช้งาน (คน)",
    yaxis_title="",
    margin=dict(t=60, b=60, l=120, r=40),
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig2.show()

# ---------------------------------------------------------
# กราฟที่ 3: กราฟเปรียบเทียบ S_Occasion แบ่งตาม Cluster_ID
# ---------------------------------------------------------
fig3 = px.histogram(
    df_filtered, 
    x='S_Occasion', 
    color='Cluster_ID', 
    title='จำนวนลูกค้าในแต่ละ Cluster แบ่งตามแพลตฟอร์มที่ใช้งานประจำ (S_Occasion)', 
    barmode='group', 
    template='plotly_white'
)
fig3.show()

# ---------------------------------------------------------
# กราฟที่ 4: กราฟพฤติกรรมการใช้สื่อช่วงเทศกาลสงกรานต์ (Festival)
# ---------------------------------------------------------
fig4 = px.histogram(
    df_filtered, 
    y='S_Usage(festival)', 
    color='Cluster_ID', 
    title='พฤติกรรมการใช้สื่อช่วงเทศกาลสงกรานต์', 
    barmode='group', 
    template='plotly_white'
)
fig4.show()

# %%
import pandas as pd
import plotly.express as px

# 1. โหลดข้อมูล
df = pd.read_csv('cleaned_data.csv')

# กำหนดธีมสีกาแฟ (Coffee Palette): น้ำตาลเข้ม, น้ำตาลกลาง, เบจ/ครีม
coffee_colors = ['#4A3B32', '#8C6D58', '#D4B28D']

# ---------------------------------------------------------
# กราฟที่ 1: Donut Chart สัดส่วนช่องทางที่มีอิทธิพล (S_Influence)
# ---------------------------------------------------------
main_cats = ['โซเชียลมีเดีย', 'แพลตฟอร์มวิดีโอ', 'โทรทัศน์', 'สื่อ ณ จุดขาย', 'แอปพลิเคชั่นแชท/ส่งเมสเสจ']
cat_counts = {cat: df['S_Influence'].str.contains(cat).sum() for cat in main_cats}

other_cats = ['เว็บไซต์', 'บิลบอร์ด/ป้ายโฆษณา', 'รถเมล์/รถไฟฟ้า']
other_sum = sum([df['S_Influence'].str.contains(cat).sum() for cat in other_cats])
cat_counts['อื่นๆ'] = other_sum

df_pie = pd.DataFrame(list(cat_counts.items()), columns=['Platform', 'Count'])

fig1 = px.pie(
    df_pie, 
    values='Count', 
    names='Platform', 
    title='สัดส่วนช่องทางที่มีอิทธิพลต่อการตัดสินใจซื้อ (S_Influence)', 
    hole=0.4, # เปลี่ยนเป็น Donut Chart เพื่อความทันสมัย
    color_discrete_sequence=coffee_colors
)
fig1.update_traces(textinfo='percent+label', textfont_size=12)
fig1.update_layout(
    title_font=dict(size=18, family="Tahoma", color="#333"),
    legend=dict(orientation="h", yanchor="bottom", y=-0.2, xanchor="center", x=0.5),
    margin=dict(t=60, b=60, l=40, r=40),
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig1.show()

# ---------------------------------------------------------
# กราฟที่ 2: Bar Chart แนวนอน เรียงลำดับ (Sorted Bar Chart)
# ---------------------------------------------------------
all_categories = main_cats + other_cats
counts = {cat: df['S_Influence'].str.contains(cat).sum() for cat in all_categories}

df_influence = pd.DataFrame(list(counts.items()), columns=['Platform', 'Count']).sort_values(by='Count', ascending=True)

fig2 = px.bar(
    df_influence, 
    x='Count', 
    y='Platform', 
    title='จำนวนผู้ได้รับอิทธิพลจากโฆษณาจำแนกตามช่องทาง', 
    orientation='h', 
    text_auto=True,
    color='Count',
    color_continuous_scale='Oranges' # ใช้โทนสีส้ม-น้ำตาลสไตล์กาแฟ
)
fig2.update_layout(
    title_font=dict(size=18, family="Tahoma", color="#333"),
    xaxis_title="จำนวนผู้ใช้งาน (คน)",
    yaxis_title="",
    margin=dict(t=60, b=60, l=120, r=40),
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig2.show()

# ---------------------------------------------------------
# กราฟที่ 3: กราฟเปรียบเทียบ S_Occasion แบ่งตาม Cluster_ID
# ---------------------------------------------------------
fig3 = px.histogram(
    df_filtered, 
    x='S_Occasion', 
    color='Cluster_ID', 
    title='จำนวนลูกค้าในแต่ละ Cluster แบ่งตามแพลตฟอร์มที่ใช้งานประจำ (S_Occasion)', 
    barmode='group', 
    color_discrete_sequence=coffee_colors, # ใช้สีสีกาแฟ
    template='plotly_white'
)
fig3.update_layout(
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig3.show()

# ---------------------------------------------------------
# กราฟที่ 4: กราฟพฤติกรรมการใช้สื่อช่วงเทศกาลสงกรานต์ (Festival)
# ---------------------------------------------------------
fig4 = px.histogram(
    df_filtered, 
    y='S_Usage(festival)', 
    color='Cluster_ID', 
    title='พฤติกรรมการใช้สื่อช่วงเทศกาลสงกรานต์', 
    barmode='group', 
    color_discrete_sequence=coffee_colors, # ใช้สีสีกาแฟ
    template='plotly_white'
)
fig4.update_layout(
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig4.show()

# %%
import pandas as pd
import plotly.express as px

# 1. โหลดข้อมูล
df = pd.read_csv('cleaned_data.csv')

# กำหนดธีมสีตามรูปที่ต้องการ: น้ำเงินเข้ม, เขียวอมฟ้า(Teal), เทา
custom_colors = ['#1d5ac4', '#21cdb6', '#8f8f8f']

# ---------------------------------------------------------
# กราฟที่ 1: Donut Chart สัดส่วนช่องทางที่มีอิทธิพล (S_Influence)
# ---------------------------------------------------------
main_cats = ['โซเชียลมีเดีย', 'แพลตฟอร์มวิดีโอ', 'โทรทัศน์', 'สื่อ ณ จุดขาย', 'แอปพลิเคชั่นแชท/ส่งเมสเสจ']
cat_counts = {cat: df['S_Influence'].str.contains(cat).sum() for cat in main_cats}

other_cats = ['เว็บไซต์', 'บิลบอร์ด/ป้ายโฆษณา', 'รถเมล์/รถไฟฟ้า']
other_sum = sum([df['S_Influence'].str.contains(cat).sum() for cat in other_cats])
cat_counts['อื่นๆ'] = other_sum

df_pie = pd.DataFrame(list(cat_counts.items()), columns=['Platform', 'Count'])

fig1 = px.pie(
    df_pie, 
    values='Count', 
    names='Platform', 
    title='สัดส่วนช่องทางที่มีอิทธิพลต่อการตัดสินใจซื้อ (S_Influence)', 
    hole=0.4, # เปลี่ยนเป็น Donut Chart เพื่อความทันสมัย
    color_discrete_sequence=custom_colors
)
fig1.update_traces(textinfo='percent+label', textfont_size=12)
fig1.update_layout(
    title_font=dict(size=18, family="Tahoma", color="#333"),
    legend=dict(orientation="h", yanchor="bottom", y=-0.2, xanchor="center", x=0.5),
    margin=dict(t=60, b=60, l=40, r=40),
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig1.show()

# ---------------------------------------------------------
# กราฟที่ 2: Bar Chart แนวนอน เรียงลำดับ (Sorted Bar Chart)
# ---------------------------------------------------------
all_categories = main_cats + other_cats
counts = {cat: df['S_Influence'].str.contains(cat).sum() for cat in all_categories}

df_influence = pd.DataFrame(list(counts.items()), columns=['Platform', 'Count']).sort_values(by='Count', ascending=True)

fig2 = px.bar(
    df_influence, 
    x='Count', 
    y='Platform', 
    title='จำนวนผู้ได้รับอิทธิพลจากโฆษณาจำแนกตามช่องทาง', 
    orientation='h', 
    text_auto=True,
    color='Count',
    color_continuous_scale='Blues' # ใช้โทนสีฟ้าเข้มไล่ระดับ
)
fig2.update_layout(
    title_font=dict(size=18, family="Tahoma", color="#333"),
    xaxis_title="จำนวนผู้ใช้งาน (คน)",
    yaxis_title="",
    margin=dict(t=60, b=60, l=120, r=40),
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig2.show()

# ---------------------------------------------------------
# กราฟที่ 3: กราฟเปรียบเทียบ S_Occasion แบ่งตาม Cluster_ID
# ---------------------------------------------------------
fig3 = px.histogram(
    df_filtered, 
    x='S_Occasion', 
    color='Cluster_ID', 
    title='จำนวนลูกค้าในแต่ละ Cluster แบ่งตามแพลตฟอร์มที่ใช้งานประจำ (S_Occasion)', 
    barmode='group', 
    color_discrete_sequence=custom_colors, # ใช้สีธีมเดียวกัน
    template='plotly_white'
)
fig3.update_layout(
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig3.show()

# ---------------------------------------------------------
# กราฟที่ 4: กราฟพฤติกรรมการใช้สื่อช่วงเทศกาลสงกรานต์ (Festival)
# ---------------------------------------------------------
fig4 = px.histogram(
    df_filtered, 
    y='S_Usage(festival)', 
    color='Cluster_ID', 
    title='พฤติกรรมการใช้สื่อช่วงเทศกาลสงกรานต์', 
    barmode='group', 
    color_discrete_sequence=custom_colors, # ใช้สีธีมเดียวกัน
    template='plotly_white'
)
fig4.update_layout(
    paper_bgcolor='white',
    plot_bgcolor='white'
)
fig4.show()
